# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing IMDb Data
#
# _Author: Kevin Markham (DC)_
#
# ---

# %% [markdown]
# For project two, you will complete a serious of exercises exploring movie rating data from IMDb.
#
# For these exercises, you will be conducting basic exploratory data analysis on IMDB's movie data, looking to answer such questions as:
#
# What is the average rating per genre?
# How many different actors are in a movie?
#
# This process will help you practice your data analysis skills while becoming comfortable with Pandas.

# %% [markdown]
# ## Basic level

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('./data/imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# #### Check the number of rows and columns.

# %%
movies.shape
# Out:
# (979, 6)

# %% [markdown]
# #### Check the data type of each column.

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# #### Calculate the average movie duration.

# %%
movies['duration'].mean()
# Out:
# 120.97957099080695

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
SortDurMax=movies['duration'].idxmax()
SortDurMin = movies['duration'].idxmin()
print('Longest:',movies.iloc[SortDurMax][1], movies.iloc[SortDurMax][4], ', Shortest:',movies.iloc[SortDurMin][1],movies.iloc[SortDurMin][4])
# Out:
# Longest: Hamlet 242 , Shortest: Freaks 64

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
movies['duration'].plot (kind='hist', bins=20)

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
movies['duration'].plot (kind='box')

# %% [markdown]
# ## Intermediate level

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
Mov_Ct=movies['content_rating'].value_counts()
print(Mov_Ct)
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# NC-17          7
# PASSED         7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
ax=Mov_Ct.plot(kind='barh', title='Movies by Content Rating')
ax.set_xlabel("Count")
ax.set_ylabel("Content Rating");

# %%
movies.head(50)
# Out:
#     star_rating                                              title  \
# 0           9.3                           The Shawshank Redemption
# 1           9.2                                      The Godfather
# 2           9.1                             The Godfather: Part II
# 3           9.0                                    The Dark Knight
# 4           8.9                                       Pulp Fiction
# 5           8.9                                       12 Angry Men
# 6           8.9                     The Good, the Bad and the Ugly
# 7           8.9      The Lord of the Rings: The Return of the King
# 8           8.9                                   Schindler's List
# 9           8.9                                         Fight Club
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
movies['content_rating']=['UNRATED' if ((x=='NOT RATED')|(x=='APPROVED')|(x=='PASSED')|(x=='GP')) else x for x in movies['content_rating']]

# %%
movies.head(100)
# Out:
#     star_rating                                              title  \
# 0           9.3                           The Shawshank Redemption
# 1           9.2                                      The Godfather
# 2           9.1                             The Godfather: Part II
# 3           9.0                                    The Dark Knight
# 4           8.9                                       Pulp Fiction
# 5           8.9                                       12 Angry Men
# 6           8.9                     The Good, the Bad and the Ugly
# 7           8.9      The Lord of the Rings: The Return of the King
# 8           8.9                                   Schindler's List
# 9           8.9                                         Fight Club
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
movies['content_rating']=['NC-17' if ((x=='X')|(x=='TV-MA')) else x for x in movies['content_rating']]

# %%
movies['content_rating'].value_counts()
# Out:
# R          460
# PG-13      189
# UNRATED    160
# PG         123
# G           32
# NC-17       12
# Name: content_rating, dtype: int64

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
movies.isnull().sum()
#len(movies)-movies.count()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
movies['content_rating']=['UNRATED' if movies['content_rating'].isnull() else x for x in movies['content_rating']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-6b55b47211e0> in <module>()
# ----> 1 movies['content_rating']=['UNRATED' if movies['content_rating'].isnull() else x for x in movies['content_rating']]
#
# <ipython-input-90-6b55b47211e0> in <listcomp>(.0)
# ----> 1 movies['content_rating']=['UNRATED' if movies['content_rating'].isnull() else x for x in movies['content_rating']]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1119         raise ValueError("The truth value of a {0} is ambiguous. "
#    1120                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1121                          .format(self.__class__.__name__))
#    1122
#    1123     __bool__ = __nonzero__
#
# ...

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
long_movies = movies[movies['duration']>120]
short_movies=movies[movies['duration']<120]
print("Long Movies:",long_movies['star_rating'].mean())
print("Short Movies:",short_movies['star_rating'].mean())
# Out:
# Long Movies: 7.953669724770622
# Short Movies: 7.838666666666657

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
movies.plot(kind='scatter', x='duration', y='star_rating', alpha=.3, title='Relationship Between Duration and Star Rating');

#sns.heatmap(movies[['duration', 'star_rating']].corr())

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
movies.groupby('genre').mean().drop('star_rating', axis=1)
#movies.groupby('genre')['duration'].mean()
# Out:
#              duration
# genre
# Action     126.485294
# Adventure  134.840000
# Animation   96.596774
# Biography  131.844156
# Comedy     107.602564
# Crime      122.298387
# Drama      126.539568
# Family     107.500000
# Fantasy    112.000000
# Film-Noir   97.333333
# History     66.000000
# Horror     102.517241
# Mystery    115.625000
# Sci-Fi     109.000000
# Thriller   114.200000
# Western    136.666667

# %% [markdown]
# ## Advanced level

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
movies.boxplot(column='duration', by='content_rating', figsize=(15,8));

# %% [markdown]
# #### Determine the top rated movie (by star rating) for each genre.

# %%
movies_sorted=movies.sort_values('star_rating', ascending=False)
movies_sorted.groupby('genre').head(1)
# Out:
#      star_rating                                          title  \
# 0            9.3                       The Shawshank Redemption
# 3            9.0                                The Dark Knight
# 5            8.9                                   12 Angry Men
# 6            8.9                 The Good, the Bad and the Ugly
# 7            8.9  The Lord of the Rings: The Return of the King
# 8            8.9                               Schindler's List
# 39           8.6                                         Psycho
# 38           8.6                                    Rear Window
# 35           8.6                                   Modern Times
# 30           8.6                                  Spirited Away
# 105          8.3                                  The Third Man
# 145          8.2                                   Blade Runner
# 350          8.0                              Shadow of a Doubt
# 338          8.0                            Battleship Potemkin
# ...

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %%
dups = movies[movies['title'].duplicated(False)]
dups
# Out:
#      star_rating                            title content_rating      genre  \
# 466          7.9  The Girl with the Dragon Tattoo              R      Crime
# 482          7.8  The Girl with the Dragon Tattoo              R      Crime
# 662          7.7                        True Grit          PG-13  Adventure
# 678          7.7                   Les Miserables          PG-13      Drama
# 703          7.6                          Dracula        UNRATED     Horror
# 905          7.5                          Dracula              R     Horror
# 924          7.5                   Les Miserables          PG-13      Crime
# 936          7.4                        True Grit            NaN  Adventure
#
#      duration                                        actors_list
# 466       158  [u'Daniel Craig', u'Rooney Mara', u'Christophe...
# 482       152  [u'Michael Nyqvist', u'Noomi Rapace', u'Ewa Fr...
# 662       110  [u'Jeff Bridges', u'Matt Damon', u'Hailee Stei...
# ...

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %%
GT_10=movies['genre'].value_counts()[movies['genre'].value_counts()>10]
GT_10
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Name: genre, dtype: int64

# %%
movies.groupby('genre').star_rating.mean()[movies['genre'].value_counts()>10]
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
# Answer:

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# Answer:

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Figure out something "interesting" using the actors data!

# %%
Act_Int=movies['actors_list']
print(Act_Int)
